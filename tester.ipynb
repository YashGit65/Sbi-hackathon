# %%
import pandas as pd

# %%
df = pd.read_csv('data\processed\profile\customer_profiles-with-goals.csv')
for i in df['goals'].head(1):
    print(i)
# Out:
# [{"goal": "Build Emergency Fund", "confidence": 0.95}, {"goal": "Retirement Planning", "confidence": 0.95}, {"goal": "Child Education Planning", "confidence": 0.75}]

# %%
df = pd.read_csv("data\\recommendation\\profile-recommended.csv")

# %%
df.head()
# Out:
#   customer_id            name  phone_number  age            profession  \
# 0       C0001    Ishanvi Muni    9354581408   30  Chartered Accountant
# 1       C0002    Kamala Boase    9888601847   38               Student
# 2       C0003  Nitesh Jhaveri    6139764808   24     Marketing Manager
# 3       C0004      Fiyaz Gour    9285208580   37               Student
# 4       C0005       Osha Dash    9769881502   36  Chartered Accountant
#
#    income marital_status location  total_expenses  investment_amount  ...  \
# 0   23528        Married     Pune           97995            29490.0  ...
# 1   56903        Married  Chennai           39075            11960.0  ...
# 2  207905        Married     Agra           57476             5128.0  ...
# 3  224398         Single     Pune          108488            10063.0  ...
# 4  154242         Single   Mumbai           87065            24335.0  ...
#
#    Healthcare  Investment  Shopping  Travel  Utilities   savings  \
# ...
